# %%
import pandas as pd

# %%
df = pd.read_csv('폭염 (1990.01.01-2018.07.31)_1.csv', quotechar='"', error_bad_lines=False, encoding = "utf_16",engine = 'python')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-35-e718fee97b3b> in <module>
# ----> 1 df = pd.read_csv('폭염 (1990.01.01-2018.07.31)_1.csv', quotechar='"', error_bad_lines=False, encoding = "utf_16",engine = 'python')
#
# ...

# %%
df
# Out:
#                                                     ÁÖ¼Ò      ÀÏÀÚ  \
# 0      http://www.bigkinds.or.kr/news/newsDetailView....  19900602
# 1      http://www.bigkinds.or.kr/news/newsDetailView....  19900709
# 2      http://www.bigkinds.or.kr/news/newsDetailView....  19900710
# 3      http://www.bigkinds.or.kr/news/newsDetailView....  19900711
# 4      http://www.bigkinds.or.kr/news/newsDetailView....  19900711
# 5      http://www.bigkinds.or.kr/news/newsDetailView....  19900711
# 6      http://www.bigkinds.or.kr/news/newsDetailView....  19900711
# 7      http://www.bigkinds.or.kr/news/newsDetailView....  19900711
# 8      http://www.bigkinds.or.kr/news/newsDetailView....  19900711
# 9      http://www.bigkinds.or.kr/news/newsDetailView....  19900711
# 10     http://www.bigkinds.or.kr/news/newsDetailView....  19900711
# 11     http://www.bigkinds.or.kr/news/newsDetailView....  19900712
# 12     http://www.bigkinds.or.kr/news/newsDetailView....  19900712
# ...

# %%
pd.read_csv('폭염.csv',  error_bad_lines=False,encoding='utf-8')
# Out:
# b'Skipping line 15: expected 18 fields, saw 19\nSkipping line 71: expected 18 fields, saw 19\nSkipping line 74: expected 18 fields, saw 19\nSkipping line 79: expected 18 fields, saw 19\nSkipping line 94: expected 18 fields, saw 19\nSkipping line 110: expected 18 fields, saw 19\nSkipping line 118: expected 18 fields, saw 19\nSkipping line 120: expected 18 fields, saw 19\nSkipping line 130: expected 18 fields, saw 19\nSkipping line 137: expected 18 fields, saw 19\nSkipping line 159: expected 18 fields, saw 19\nSkipping line 168: expected 18 fields, saw 19\nSkipping line 174: expected 18 fields, saw 19\nSkipping line 190: expected 18 fields, saw 20\nSkipping line 194: expected 18 fields, saw 19\nSkipping line 210: expected 18 fields, saw 21\nSkipping line 214: expected 18 fields, saw 20\nSkipping line 222: expected 18 fields, saw 19\nSkipping line 237: expected 18 fields, saw 19\nSkipping line 245: expected 18 fields, saw 20\nSkipping line 260: expected 18 fields, saw 19\nSkipping line 
# ...

# %%
f.read_lines('폭염.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-cb032c223265> in <module>
# ----> 1 f.read_lines('폭염.csv')
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'read_lines'

# %%
f = open("폭염.csv", 'r', encoding = 'utf-8')

# %%
for i in f.readlines():
    print(i)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ...

# %%
pd.Series(f.readline())
# Out:
# 0
# dtype: object

# %%
f.readline()
# Out:
# ''

# %%
f = open("폭염 (1990.01.01-2018.07.31)_1.csv", 'r', encoding = 'cp949')
df = pd.DataFrame(f.readlines())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-63-9af81ca13b20> in <module>
#       1 f = open("폭염 (1990.01.01-2018.07.31)_1.csv", 'r', encoding = 'cp949')
# ----> 2 df = pd.DataFrame(f.readlines())
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0x81 in position 3516: illegal multibyte sequence

# %%
df
# Out:
#                                                       0
# 0     주소,일자,언론사,기고자,제목,통합 분류1,통합 분류2,통합 분류3,사건/사고 분류...
# 1     "http://www.bigkinds.or.kr/news/newsDetailView...
# 2     "http://www.bigkinds.or.kr/news/newsDetailView...
# 3     "http://www.bigkinds.or.kr/news/newsDetailView...
# 4     "http://www.bigkinds.or.kr/news/newsDetailView...
# 5     "http://www.bigkinds.or.kr/news/newsDetailView...
# 6     "http://www.bigkinds.or.kr/news/newsDetailView...
# 7     "http://www.bigkinds.or.kr/news/newsDetailView...
# 8     "http://www.bigkinds.or.kr/news/newsDetailView...
# 9     "http://www.bigkinds.or.kr/news/newsDetailView...
# 10    "http://www.bigkinds.or.kr/news/newsDetailView...
# 11    "http://www.bigkinds.or.kr/news/newsDetailView...
# 12    "http://www.bigkinds.or.kr/news/newsDetailView...
# 13    "http://www.bigkinds.or.kr/news/newsDetailView...
# 14    "http://www.bigkinds.or.kr/news/newsDetailView...
# 15    "http://www.bigkinds.or.kr/news/newsDetailView...
# ...
