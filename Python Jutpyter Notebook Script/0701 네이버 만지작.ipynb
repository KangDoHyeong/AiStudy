# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import urllib.parse

# %%
url = 'http://naver.com'
page = urlopen(url)
soup = BeautifulSoup(page,'html.parser')

# %%
print(soup.body.prettify())
# Out:
# <body class="">
#  <!-- 스킵 내비게이션 -->
#  <div class="u_skip">
#   <a href="#news_cast" onclick="document.getElementById('news_cast2').tabIndex = -1;document.getElementById('news_cast2').focus();return false;">
#    <span>
#     연합뉴스 바로가기
#    </span>
#   </a>
#   <a href="#themecast" onclick="document.getElementById('themecast').tabIndex = -1;document.getElementById('themecast').focus();return false;">
#    <span>
#     주제별캐스트 바로가기
#    </span>
#   </a>
#   <a href="#time_square" onclick="document.getElementById('time_square').tabIndex = -1;document.getElementById('time_square').focus();return false;">
#    <span>
#     타임스퀘어 바로가기
#    </span>
#   </a>
#   <a href="#shp_cst" onclick="document.getElementById('shp_cst').tabIndex = -1;document.getElementById('shp_cst').focus();return false;">
#    <span>
#     쇼핑캐스트 바로가기
#    </span>
#   </a>
#   <a href="#account" onclick="document.getElementById('account').tabIndex = -1;document.getElementById('account').focus();return false;">
# ...

# %%
Tag = soup.body.find_all("div", class_="api_atcmp_wrap _keywords", style='display:none:')

# %%
Tag = soup.body.find_all("div", class_="api_atcmp_wrap _keywords")

# %%
print(Tag[0].prettify())
# Out:
# <div class="api_atcmp_wrap _keywords" style="display:none;">
#  <div class="my_words">
#   <div class="lst_tab">
#    <ul>
#     <li class="on _recentTab">
#      <a href="javascript:;">
#       최근검색어
#      </a>
#     </li>
#     <li class="_myTab">
#      <a href="javascript:;">
#       내 검색어
#      </a>
#     </li>
#    </ul>
#   </div>
#   <div class="words _recent">
#    <ul>
#     <li data-rank="@rank@">
#      <a class="t@my@ _star _myBtn" href="javascript:;" title="내 검색어 등록">
#       <em class="spat">
#        내 검색어 등록
#       </em>
#      </a>
#      <a class="keyword" href="javascript:;">
#       @txt@
#      </a>
#      <em class="keyword_date">
#       @date@.
#      </em>
#      <a class="btn_delete spat _del" href="javascript:;" title="검색어삭제">
#       삭제
#      </a>
#      <span style="display:none">
#       @in_txt@
#      </span>
#     </li>
#    </ul>
#    <div class="info_words _recentNone" style="display:none">
#     최근검색어 내역이 없습니다.
#    </div>
# ...

# %%
url = 'http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp'
page = urlopen(url)
soup = BeautifulSoup(page,'html.parser')

# %%
title = soup.find('title').string

# %%
wf = soup.find_all('wf')

# %%
title
# Out:
# '기상청 육상 중기예보'

# %%
wf
# Out:
# [<wf><![CDATA[장마전선의 영향으로 6~7일에 남부지방과 제주도에 비가 오겠습니다.  <br />그 밖의 날은 고기압의 영향으로 맑은 날이 많겠습니다.<br />기온은 평년(최저기온: 18~22℃, 최고기온: 25~30℃) 보다 4~5일에는 조금 높겠고, 그 밖의 날은 비슷하겠습니다.<br />강수량은 평년(5~18mm)보다 남부지방과 제주도는 많겠고, 중부지방은 적겠습니다.<br /><br />* 한편, 장마전선은 6일부터 제주도남쪽먼바다에서 다시 북상할 것으로 예상되나, 북태평양고기압의 확장 정도에 따라 장마전선의 위치와 강수 영역이 달라질 수 있으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.<br />* 내륙지역을 중심으로 낮 기온이 30도 이상 올라 덥겠으니, 보건, 축산 등 폭염피해에 유의하기 바랍니다.]]></wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>구름많음</wf>,
#  <wf>구름많음</wf>,
#  <wf>구름많음</wf>,
#  <wf>구름많음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>구름많음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>구름많음</wf>,
#  <wf>구름많음</wf>,
#  <wf>구름많음</wf>,
#  <wf>구름많음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>구름많음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>맑음</wf>,
#  <wf>구름많음</wf>,
#  <wf>구름많음</wf>,
#  <wf>구름많음</wf>,
#  <wf>구름많음</wf>,
# ...

# %%
for line in wf:
    print(line.text)
# Out:
# 장마전선의 영향으로 6~7일에 남부지방과 제주도에 비가 오겠습니다.  <br />그 밖의 날은 고기압의 영향으로 맑은 날이 많겠습니다.<br />기온은 평년(최저기온: 18~22℃, 최고기온: 25~30℃) 보다 4~5일에는 조금 높겠고, 그 밖의 날은 비슷하겠습니다.<br />강수량은 평년(5~18mm)보다 남부지방과 제주도는 많겠고, 중부지방은 적겠습니다.<br /><br />* 한편, 장마전선은 6일부터 제주도남쪽먼바다에서 다시 북상할 것으로 예상되나, 북태평양고기압의 확장 정도에 따라 장마전선의 위치와 강수 영역이 달라질 수 있으니, 앞으로 발표되는 기상정보를 참고하기 바랍니다.<br />* 내륙지역을 중심으로 낮 기온이 30도 이상 올라 덥겠으니, 보건, 축산 등 폭염피해에 유의하기 바랍니다.
# 맑음
# 맑음
# 맑음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 맑음
# 구름많음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 맑음
# 구름많음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 맑음
# 구름많음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 맑음
# 구름많음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 맑음
# 구름많음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 맑음
# 구름많음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 맑음
# 구름많음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 맑음
# 구름많음
# 맑음
# 맑음
# ...

# %%
url = 'c:/Users//fire7//Desktop//KSA 모아놓아요//modeule04//ch01//CSS_Exam.html'
# page = urlopen(url)
soup = BeautifulSoup(url,'html.parser')
# Out:
# c:\users\fire7\appdata\local\programs\python\python37\lib\site-packages\bs4\__init__.py:272: UserWarning: "b'c:/Users//fire7//Desktop//KSA \xeb\xaa\xa8\xec\x95\x84\xeb\x86\x93\xec\x95\x84\xec\x9a\x94//modeule04//ch01//CSS_Exam.html'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)

# %%
soup
# Out:
# c:/Users//fire7//Desktop//KSA 모아놓아요//modeule04//ch01//CSS_Exam.html

# %%
with open('c:/Users//fire7//Desktop//KSA 모아놓아요//modeule04//ch01//CSS_Exam.html', mode = 'r',encoding='UTF-8') as f:
    soup = BeautifulSoup(f, 'html.parser')
    h1 = soup.select_one('div#meigen>h1').string # 아이디 속성이 이거인 거의 하위태그의 h1
    print(h1)
    li_list = soup.select('div#meigen>ul.items>li') # #은 클래스, .은 아이디
    for line in li_list:
        print(line.get_text())
    li = soup.select_one('div#meigen>ul.items>li:nth-child(3)')
    print(li)
#     print('hi')
# Out:
# 파이썬 프로그램
# Python 기초
# GUI 프로그래밍
# Python 데이타
# Django 기초
# Python 활용
# Python 팁
# Contact
# 검색
# <li><a href="/Python/Data">Python 데이타</a></li>

# %%
#primaryContent > table > tbody > tr.pos_rel > td.cb.pos_rel > form:nth-child(4) > table > tbody > tr:nth-child(14) > td.subject > a:nth-child(1)

# %%
temp = 1
url = 'https://finance.naver.com/marketindex/exchangeDegreeCountQuote.nhn?marketindexCd=FX_USDKRW&page=%d'%temp
page = urlopen(url)
soup = BeautifulSoup(page,'html.parser')

# %%
x = soup.find_all('tr', class_='up')

# %%
body > div > table > tbody > tr:nth-child(1) > td:nth-child(2)
# Out:
# <tr class="up">
# <td class="count">324회</td>
# <td class="num">1,161.00</td>
# <td class="num"><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 5.50</td>
# <td>1,181.31</td>
# <td>1,140.69</td>
# <td>1,172.30</td>
# <td>1,149.70</td>
# <td>
#
#
# 		1,174.93
#
# 	</td>
# <td class="last_td">
#
#
# 		1,148.34
#
# 	</td>
# </tr>
# <tr class="up">
# <td class="count">323회</td>
# <td class="num">1,160.50</td>
# <td class="num"><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 5.00</td>
# <td>1,180.80</td>
# <td>1,140.20</td>
# <td>1,171.80</td>
# <td>1,149.20</td>
# <td>
#
#
# 		1,174.42
#
# 	</td>
# <td class="last_td">
#
#
# 		1,147.84
#
# 	</td>
# </tr>
# <tr class="up">
# <td class="count">322회</td>
# <td class="num">1,160.00</td>
# <td class="num"><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/> 4.50</td>
# <td>1,180.30</td>
# <td>1,139.70</td>
# ...

# %%
soup.select('body > div > table > tbody > tr:nth-child(1)')
# Out:
# []

# %%
for i in x:
    print(i.td.next_sibling.next_sibling.string)
# Out:
# 1,136.50
# 1,140.50
# 1,145.00
# 1,138.00
# 1,137.00

# %%
for i in range(1,11):
    print(soup.select('body > div > table > tbody > tr:nth-child(%d) > td:nth-child(1)'%i)[0].string,
         soup.select('body > div > table > tbody > tr:nth-child(%d) > td:nth-child(2)'%i)[0].string)
# Out:
# 199회 1,170.60
# 198회 1,170.40
# 197회 1,170.50
# 196회 1,170.60
# 195회 1,170.70
# 194회 1,170.60
# 193회 1,170.50
# 192회 1,170.50
# 191회 1,170.40
# 190회 1,170.30

# %%
for temp in range(3,7):
    url = 'https://finance.naver.com/marketindex/exchangeDegreeCountQuote.nhn?marketindexCd=FX_USDKRW&page=%d'%temp
    page = urlopen(url)
    soup = BeautifulSoup(page,'html.parser')
    print('page : ',temp)
    for i in range(1,11):
        print(soup.select('body > div > table > tbody > tr:nth-child(%d) > td:nth-child(1)'%i)[0].string,
             soup.select('body > div > table > tbody > tr:nth-child(%d) > td:nth-child(2)'%i)[0].string)
# Out:
# page :  3
# 306회 1,158.90
# 305회 1,158.70
# 304회 1,158.70
# 303회 1,158.80
# 302회 1,158.60
# 301회 1,158.70
# 300회 1,158.80
# 299회 1,158.90
# 298회 1,159.00
# 297회 1,158.90
# page :  4
# 296회 1,159.00
# 295회 1,159.20
# 294회 1,159.00
# 293회 1,159.10
# 292회 1,159.00
# 291회 1,158.80
# 290회 1,159.00
# 289회 1,159.20
# 288회 1,159.30
# 287회 1,159.40
# page :  5
# 286회 1,159.50
# 285회 1,159.40
# 284회 1,159.30
# 283회 1,159.40
# 282회 1,159.20
# 281회 1,158.90
# 280회 1,158.80
# 279회 1,158.90
# 278회 1,158.60
# 277회 1,158.30
# page :  6
# 276회 1,158.20
# 275회 1,158.30
# 274회 1,158.40
# 273회 1,158.30
# 272회 1,158.20
# 271회 1,158.00
# 270회 1,157.80
# 269회 1,157.60
# 268회 1,157.50
# 267회 1,157.50

# %%
for temp in range(3,7):
    url = 'https://finance.naver.com/marketindex/exchangeDailyQuote.nhn?marketindexCd=FX_USDKRW&page=%s'%temp
    page = urlopen(url)
    soup = BeautifulSoup(page,'html.parser')
    print('page : ',temp)
    for i in range(1,11):
        print(soup.select('body > div > table > tbody > tr:nth-child(%d) > td:nth-child(1)'%i)[0].string,'\t',
             soup.select('body > div > table > tbody > tr:nth-child(%d) > td:nth-child(2)'%i)[0].string)
# Out:
# page :  3
# 2019.05.31 	 1,191.50
# 2019.05.30 	 1,191.50
# 2019.05.29 	 1,194.50
# 2019.05.28 	 1,189.50
# 2019.05.27 	 1,185.50
# 2019.05.24 	 1,188.00
# 2019.05.23 	 1,191.50
# 2019.05.22 	 1,190.00
# 2019.05.21 	 1,195.00
# 2019.05.20 	 1,195.00
# page :  4
# 2019.05.17 	 1,195.50
# 2019.05.16 	 1,190.00
# 2019.05.15 	 1,190.50
# 2019.05.14 	 1,187.50
# 2019.05.13 	 1,187.50
# 2019.05.10 	 1,178.00
# 2019.05.09 	 1,182.50
# 2019.05.08 	 1,172.50
# 2019.05.07 	 1,169.00
# 2019.05.03 	 1,170.00
# page :  5
# 2019.05.02 	 1,164.50
# 2019.04.30 	 1,167.00
# 2019.04.29 	 1,160.50
# 2019.04.26 	 1,161.00
# 2019.04.25 	 1,163.00
# 2019.04.24 	 1,151.00
# 2019.04.23 	 1,142.50
# 2019.04.22 	 1,141.50
# 2019.04.19 	 1,136.50
# 2019.04.18 	 1,138.00
# page :  6
# 2019.04.17 	 1,133.50
# 2019.04.16 	 1,136.50
# 2019.04.15 	 1,133.50
# 2019.04.12 	 1,137.00
# 2019.04.11 	 1,140.50
# 2019.04.10 	 1,138.50
# 2019.04.09 	 1,140.50
# 2019.04.08 	 1,145.00
# 2019.04.05 	 1,138.00
# ...

# %%
y = soup.find_all('td',class_='date')
for line in y:
    print(line.string)
# Out:
# 2019.04.17
# 2019.04.16
# 2019.04.15
# 2019.04.12
# 2019.04.11
# 2019.04.10
# 2019.04.09
# 2019.04.08
# 2019.04.05
# 2019.04.04

# %%
y = soup.find_all('td',class_='num')
for line in y:
    print(line.get_text())
# Out:
# 1,133.50
#   3.00
# 1,136.50
#  3.00
# 1,133.50
#   3.50
# 1,137.00
#   3.50
# 1,140.50
#  2.00
# 1,138.50
#   2.00
# 1,140.50
#   4.50
# 1,145.00
#  7.00
# 1,138.00
#  1.00
# 1,137.00
#  2.50

# %%
y[1].get_text().strip()
# Out:
# '3.00'

# %%
if 'alt' in str(y[1].img):
    dawdw
# Out:
# True

# %%
y[1].img
# Out:
# <img alt="하락" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_down.gif" width="7"/>
