# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
c = np.array([[1,2],[3,4]])
print(c)
# Out:
# [[1 2]
#  [3 4]]

# %%
d = np.array([[1],[2]])
print(d)
# Out:
# [[1]
#  [2]]

# %%
c*d
# Out:
# array([[1, 2],
#        [6, 8]])

# %%
b = np.array([1,2])

# %%
b*c
# Out:
# array([[1, 4],
#        [3, 8]])

# %%
np.linalg.norm(d)
# Out:
# 2.23606797749979

# %%
x = np.ones(1000)
x2 = np.arange(1,1001)
print(x.dot(x2))
# Out:
# 500500.0

# %%
import time

# %%
time.time()
# Out:
# 1560999993.989729

# %%
tt= time.time()
sum=0

for i in range(len(x)):
    sum+=x[i]*x2[i]
print(sum)
print(time.time()-tt)
# Out:
# 500500.0
# 0.0014882087707519531

# %%
tt= time.time()
print(x.dot(x2))
print(time.time()-tt)
# Out:
# 500500.0
# 0.0004963874816894531

# %%
from matplotlib import pyplot as plt

# %%
def f(w0,w1):
    return w0**2 + w0 * w1 +3
def df_dw0(w0,w1):
    return 2*w0+2*w1
def df_dw1(w0,w1):
    return 2*w0+0*w1

w_range=2
dw=0.25


w0 = np.arange(-w_range,w_range+dw,dw)
w1 = np.arange(-w_range,w_range+dw,dw)

wn=w0.shape[0]

ww0,ww1=np.meshgrid(w0,w1)
ff=np.zeros((len(w0),len(w1)))

dff_dw0=np.zeros((len(w0),len(w1)))
dff_dw1=np.zeros((len(w0),len(w1)))

for i0 in range(wn):
    for i1 in  range(wn):
        ff[i1,i0] = f(w0[i0],w1[i1])
        dff_dw0[i1,i0]=df_dw0(w0[i0],w1[i1])
        dff_dw1[i1,i0]=df_dw1(w0[i0],w1[i1])

# %%
plt.figure(figsize=(20,8))
plt.subplots_adjust(wspace=0.3)
plt.subplot(1,2,1)
cont=plt.contour(ww0,ww1,ff,10,colors='k')
cont.clabel(fmt='%2.0f',fontsize=8)
plt.xticks(range(-w_range,w_range+1,1))
plt.yticks(range(-w_range,w_range+1,1))
plt.xlim=(-w_range-0.5, w_range+.5)
plt.ylim=(-w_range- .5, w_range+ .5)
plt.xlabel('$w_0$', fontsize=14)
plt.ylabel('$w_1$', fontsize=14)

plt.subplot(1,2,2)
plt.quiver(ww0,ww1,dff_dw0,dff_dw1)
plt.xlabel('$w_0$', fontsize=14)
plt.ylabel('$w_1$', fontsize=14) # 달러는 w0을 수식처럼 나오도록함 
plt.xticks(range(-w_range,w_range+1,1))
plt.yticks(range(-w_range,w_range+1,1))
plt.xlim=(-w_range-0.5, w_range+.5)
plt.ylim=(-w_range- .5, w_range+ .5)

plt.show()

# %%
A = np.array([1,2,3])
B = np.array([4,5,6])
print(A.dot(B))
print(A*B)
# Out:
# 32
# [ 4 10 18]

# %%
A = np.array([[1,2],[3,4]])
invA = np.linalg.inv(A)
print(invA)
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
# %matplotlib inline

# %%
x = np.linspace(-4,2,100)
y = 2**x
y2 = 3**x
y3 = 0.5**x
plt.figure(figsize=(5,5))
plt.plot(x,y,'black',linewidth=3, label='$y=2^x$')
plt.plot(x,y2,'cornflowerblue',linewidth=3, label='$y=3^x$')
plt.plot(x,y3,'gray',linewidth=3, label='$y=0.5^x$')
plt.ylim(2,2)
plt.xlim(2,2)
plt.grid(True)
plt.legend(loc='upper left')
plt.show()
# Out:
# c:\users\fire7\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Attempting to set identical bottom == top == 2 results in singular transformations; automatically expanding.
#   if __name__ == '__main__':
# c:\users\fire7\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Attempting to set identical left == right == 2 results in singular transformations; automatically expanding.
#   # Remove the CWD from sys.path while we load stuff.

# %%
x = np.linspace(-8,8,100)
y = 2**x
x2 = np.linspace(0.001,8,10)
y2 = np.log(x2)/np.log(2)

plt.figure(figsize=(5,5))
plt.plot(x,y,'black',linewidth=3)
plt.plot(x2,y2,'cornflowerblue',linewidth=3)
plt.plot(x,x,'black',linewidth=1,linestyle='--')
plt.ylim(-9,8)
plt.xlim(-8,8)
# Out:
# (-8, 8)

# %%
x = np.linspace(-4,4,100)
y = (x-1)**2+2
logy = np.log(y)

plt.figure(figsize=(5,5))
plt.plot(x,y,'black',linewidth=3)
plt.plot(x,logy,'cornflowerblue',linewidth=3)
plt.xticks(range(-4,9,1))
plt.yticks(range(-4,5,1))
plt.ylim(-4,8)
plt.xlim(-4,4)
plt.grid(True)
plt.show()

# %%
x = np.linspace(-10,10,100)
y= 1/(1+np.exp(-x))

plt.figure(figsize=(5,5))
plt.plot(x,y,'black',linewidth=3)
plt.grid(True)
plt.ylim(-1,2)
plt.show()

# %%
def softmax(x0,x1,x2):
    u=np.exp(x0)+np.exp(x1)+np.exp(x2)
    return np.exp(x0)/u,np.exp(x1)/u,np.exp(x2)/u
y = softmax(2,1,-1)
print(y)
# Out:
# (0.7053845126982412, 0.2594964603424191, 0.03511902695933972)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
xn=20
x0=np.linspace(-5,5,xn)
x1 = np.linspace(-5,5,xn)
y = np.zeros((xn,xn,3))
for i in range(xn):
    for j in range(xn):
        y[j,i,:]=softmax(x0[i],x1[j],1)

xx0,xx1=np.meshgrid(x0,x1)
plt.figure(figsize=(8,5))
for i in range(2):
    ax=plt.subplot(1,2,i+1,projection=('3d'))
    ax.plot_surface(xx0,xx1,y[:,:,i],
                   rstride=1, cstride=1, alpha=0.3, color='b',edgecolor='black')
    ax.set_xlabel('$x_0$', fontsize=14)
    ax.set_ylabel('$x_1$', fontsize=14)
    ax.view_init(40,-125)
    
plt.show()

# %%
def gauss(mu,sigma,a):
    return a*np.exp(-(x-mu)**2 / sigma**2)

x = np.linspace(-4,4,100)
plt.figure(figsize=(4,4))
plt.plot(x,gauss(0,1,1),'black',linewidth=3)
plt.plot(x,gauss(2,3,0.5),'grey',linewidth=3)
plt.plot(x,gauss(0,3,2),'b',linewidth=3)
plt.ylim(-.5,1.5)
plt.xlim(-4,4)
plt.grid(True)
plt.show()
