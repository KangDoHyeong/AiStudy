# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import urllib.parse

# %% [markdown]
# # hello

# %%
url_base= 'data:image/jpeg;base64,...'

# %%
page = urlopen( url_base )

# %%
page

# %%
soup = BeautifulSoup( page, 'html.parser')

# %%
soup

# %%
# 링크에서 바로 다운로드
url = 'http://uta.pw/shodou/img/28/214.png'
savename = 'tes_download2.png'
urllib.request.urlretrieve(url2, savename)
# Out:
# ('tes_download2.png', <http.client.HTTPMessage at 0x29fa4b7f278>)

# %%
url2 = 'https://scontent-dfw5-1.cdninstagram.com/vp/5eb6f11e69c4b30624ddcaaf8289c01e/5D8D0794/t51.2885-15/e35/s320x320/21576930_147902679139261_4357611919452930048_n.jpg?_nc_ht=scontent-dfw5-1.cdninstagram.com&ig_cache_key=MTYwMzk2NzA2MTU1Nzc5OTkxMg%3D%3D.2'

# %%
# 메모리에 올렸다가 다운로드 
url = 'http://uta.pw/shodou/img/28/214.png'
savename = 'tes_download2.png'
tmp = urllib.request.urlopen(url).read()

with open(savename, mode='wb') as f:
    f.write(tmp)

    f.close()

# %%
url = 'http://api.aoikujira.com/ip/ini'
tmp = urllib.request.urlopen(url).read()
print(tmp)
text = tmp.decode('utf-8') # 텍스트로 변환하기 위해서 ~~
print()
print(text)
# Out:
# b'[ip]\nAPI_URI=http://api.aoikujira.com/ip/get.php\nREMOTE_ADDR=115.88.249.138\nREMOTE_HOST=115.88.249.138\nREMOTE_PORT=52222\nHTTP_HOST=api.aoikujira.com\nHTTP_USER_AGENT=Python-urllib/3.7\nHTTP_ACCEPT_LANGUAGE=\nHTTP_ACCEPT_CHARSET=\nSERVER_PORT=80\nFORMAT=ini\n\n'
#
# [ip]
# API_URI=http://api.aoikujira.com/ip/get.php
# REMOTE_ADDR=115.88.249.138
# REMOTE_HOST=115.88.249.138
# REMOTE_PORT=52222
# HTTP_HOST=api.aoikujira.com
# HTTP_USER_AGENT=Python-urllib/3.7
# HTTP_ACCEPT_LANGUAGE=
# HTTP_ACCEPT_CHARSET=
# SERVER_PORT=80
# FORMAT=ini

# %%
API = 'http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp'

# %%
value={'stnid':'108'}

# %%
params = urllib.parse.urlencode(value) 
# params = 'stnid=108' 이라고 해도됨

# %%
print(params)
# Out:
# stnid=108

# %%
url = API+'?'+params

# %%
res = urllib.request.urlopen(url)

# %%
data = res.read()
# data = urllib.request.urlopen(url).read()

# %%
text = data.decode('utf-8')

# %%
print(text)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2019년 07월 01일 (월)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2019년 07월 01일 (월)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# 	<header>
# 		<title>전국 육상중기예보</title>
# 		<tm>201907010600</tm>
# ...

# %%
API = 'http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp'
value={'stnid':'156'}
params = urllib.parse.urlencode(value) 
url = API+'?'+params
data = urllib.request.urlopen(url).read()
text = data.decode('utf-8')
print(text)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2019년 07월 01일 (월)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2019년 07월 01일 (월)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# 	<header>
# 		<title>전국 육상중기예보</title>
# 		<tm>201907010600</tm>
# ...

# %%
url_base = 'http://www.weather.go.kr/weather/forecast/mid-term-rss3.jsp'
page = urlopen( url_base )
soup = BeautifulSoup( page, 'html.parser')

# %%
print(soup)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubdate>2019년 07월 01일 (월)요일 06:00</pubdate>
# <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2019년 07월 01일 (월)요일 06:00 발표</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# <header>
# <title>전국 육상중기예보</title>
# <tm>201907010600</tm>
# ...

# %%
html = '''
    <html>
        <head></head>
        <body>
            <title>으아아</title>
            <h1>스크래핑이란?</h1>
            <a href='https:naver.com'>네이버로 가는길</a>
            <P>hello</P>
            <h1>안에넣어요
                <P>hi</P>
            </h1>
        </body>
    <html>
'''
print(html)
# Out:
#     <html>
#         <head></head>
#         <body>
#             <title>으아아</title>
#             <h1>스크래핑이란?</h1>
#             <a href='https:naver.com'>네이버로 가는길</a>
#             <P>hello</P>
#             <h1>안에넣어요
#                 <P>hi</P>
#             </h1>
#         </body>
#     <html>

# %%
bs = BeautifulSoup(html,'html.parser')

# %%
k = bs.find_all('p')

# %%
k[0].get_text()
# Out:
# 'hello'

# %%
print(bs.text.strip())
# Out:
# 으아아
# 스크래핑이란?
# 네이버로 가는길
# hello
# hi

# %%
print(bs.prettify())
# Out:
# <html>
#  <head>
#  </head>
#  <body>
#   <title>
#    으아아
#   </title>
#   <h1>
#    스크래핑이란?
#   </h1>
#   <a href="https:naver.com">
#    네이버로 가는길
#   </a>
#   <p>
#    hello
#   </p>
#   <p>
#    hi
#   </p>
#  </body>
#  <html>
#  </html>
# </html>

# %%
bs.body.p.next_sibling
# Out:
# '\n'

# %%
bs.body.p.previous_sibling
# Out:
# '\n'

# %%
bs.body.p.next_sibling.next_sibling
# Out:
# <p>hi</p>

# %%
bs.body.p.previous_sibling.previous_sibling
# Out:
# <a href="https:naver.com">네이버로 가는길</a>

# %%
bs.body.a.get_text()
# Out:
# '네이버로 가는길'
