# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import RMSprop,SGD
import numpy as np
from tensorflow.keras.layers import Activation
import matplotlib.pyplot as plt

# %%
x_data = np.array([2,4,5,7,8,10,25])
y_data = np.array([0,0,0,1,1,1,1])

model = Sequential()
model.add(Dense(1, input_dim=1))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd)
# model.compile(loss='binary_crossentropy', optimizer=sgd)
# 옵티마이저는 경사하강법의 일종인 확률적 경사 하강법 sgd를 사용합니다.
# 손실 함수(Loss function)는 binary_crossentropy(이진 크로스 엔트로피)를 사용합니다.
model.fit(x_data, y_data, epochs=200)

y_predict = model.predict(np.array([5]))
print(y_predict)
print(int(y_predict > 0.5))
# Out:
# Epoch 1/200
# 7/7 [==============================] - 1s 207ms/sample - loss: 0.5832
# Epoch 2/200
# 7/7 [==============================] - 0s 829us/sample - loss: 0.5443
# Epoch 3/200
# 7/7 [==============================] - 0s 574us/sample - loss: 0.5374
# Epoch 4/200
# 7/7 [==============================] - 0s 588us/sample - loss: 0.5351
# Epoch 5/200
# 7/7 [==============================] - 0s 444us/sample - loss: 0.5329
# Epoch 6/200
# 7/7 [==============================] - 0s 487us/sample - loss: 0.5306
# Epoch 7/200
# 7/7 [==============================] - 0s 293us/sample - loss: 0.5285
# Epoch 8/200
# 7/7 [==============================] - 0s 561us/sample - loss: 0.5263
# Epoch 9/200
# 7/7 [==============================] - 0s 807us/sample - loss: 0.5241
# Epoch 10/200
# 7/7 [==============================] - 0s 440us/sample - loss: 0.5220
# Epoch 11/200
# 7/7 [==============================] - 0s 289us/sample - loss: 0.5199
# Epoch 12/200
# ...

# %%
plt.plot(x_data, model.predict(x_data), 'b', x_data,y_data, '*')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
