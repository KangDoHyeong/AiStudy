# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.rcsetup

# %%
matplotlib.rcParams['font.family'] = 'Malgun Gothic'

# %%
df = pd.read_csv("ch02_data/APT.csv",skiprows=7, header=0,index_col='id',encoding='utf-8',na_values=[" ","."])
AreaTbl = pd.value_counts(df.Area)

# %%
AreaTbl = pd.value_counts(df['Area'])
plt.bar(AreaTbl.index,AreaTbl,bottom=10,color='gray',edgecolor='blue')
plt.show()

# %%
AreaTbl
# Out:
# 동북권    140
# 동남권     92
# 서북권     81
# 서남권     76
# 도심권     10
# Name: Area, dtype: int64

# %%
plt.pie(AreaTbl, explode=(0,0,0.3,0,0),labels=AreaTbl.index, autopct="%2.1f%%",shadow=True)
plt.show()

# %%
plt.pie(AreaTbl)
plt.show()

# %%
df.head()
# Out:
#       Area UseDistrict Option     FAR       Price
# id
# apt01  도심권  제2종 일반주거지역   풀옵션형  132.72  515.051949
# apt02  도심권  제2종 일반주거지역   풀옵션형  184.99         NaN
# apt03  NaN        상업지역    기본형     NaN  364.319535
# apt04  도심권        상업지역   풀옵션형  493.08  410.945530
# apt05  도심권       준주거지역    기본형  349.65  616.975986

# %%
plt.boxplot([df.dropna()['Price'],df.dropna()['FAR']],notch=True,vert=False,showmeans=True,labels=["price!!",'qq'])
plt.show()

# %%
plt.boxplot(df.dropna()['FAR'])
plt.show()

# %%
df[['FAR','Price']].head()
# Out:
#           FAR       Price
# id
# apt01  132.72  515.051949
# apt02  184.99         NaN
# apt03     NaN  364.319535
# apt04  493.08  410.945530
# apt05  349.65  616.975986

# %%
plt.hist(df['FAR'],bins=[50,100,150,200,250,300,350,400],density=True)
plt.show()

# %%
plt.hist(df['FAR'],bins=6,density=True)
plt.show()

# %%
plt.plot(df['Price'],df['FAR'],'bo--')  # blue o(점) --(dash)
plt.show()

# %%
df.head()
# Out:
#       Area UseDistrict Option     FAR       Price
# id
# apt01  도심권  제2종 일반주거지역   풀옵션형  132.72  515.051949
# apt04  도심권        상업지역   풀옵션형  493.08  410.945530
# apt05  도심권       준주거지역    기본형  349.65  616.975986
# apt07  도심권  제3종 일반주거지역   풀옵션형  227.20  576.476262
# apt08  도심권        상업지역   풀옵션형  254.37  355.871886

# %%
plt.plot(df['FAR'],"b*")
plt.plot(df['Price'],"go")
plt.legend(['용적률', '임대가'], loc='upper right')
plt.show()

# %%
plt.figure(figsize=(7,5))

plt.subplot(221) # 2행 2열로 나누는데 1번쨰 위치
plt.hist(df.FAR,bins=10)

plt.subplot(224) # 2행 2열로 나누는데  4번쨰 위치
plt.hist(df.Price,bins=10)

plt.subplot(222)
plt.plot(df['FAR'],'g*')

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.subplot(211)
plt.hist(df.FAR,bins=10)
plt.subplot(223)
plt.hist(df.FAR,bins=10)
plt.subplot(224)
plt.hist(df.FAR,bins=10)
plt.show()

# %%
plt.figure(figsize=(7,5))

plt.subplot(121)
plt.hist(df.FAR,bins=10)
plt.subplot(222)
plt.hist(df.FAR,bins=10)
plt.subplot(224)
plt.hist(df.FAR,bins=10)
plt.show()

# %%
plt.figure(figsize=(7,5))

plt.subplot(221)
plt.hist(df.FAR,bins=10)
plt.subplot(333)
plt.hist(df.FAR,bins=10)
plt.subplot(336)
plt.hist(df.FAR,bins=10)
plt.subplot(338)
plt.hist(df.FAR,bins=10)
plt.show()

# %%
print(df['Price'].plot(kind='box'))
print(df['Price'].plot(kind='hist'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(df[['Price','FAR']].plot(kind='hist',alpha=0.3))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
crtab=pd.crosstab(df.Area,df.Option)

# %%
crtab # 분할표
# Out:
# Option  기본형  풀옵션형
# Area
# 도심권       3     5
# 동남권       2    90
# 동북권      29   110
# 서남권      26    50
# 서북권      38    43

# %%
AreaTbl = pd.value_counts(df.Area)
# AreaTbl.plot(kind= "pie", explode(0,0,0,0,0.1), colors=['r','g','y','b','g'])
AreaTbl.plot(kind='pie')

# %%
# df[['FAR','Price']].plot(kind='box')
df[['FAR','Price']].plot.box()
