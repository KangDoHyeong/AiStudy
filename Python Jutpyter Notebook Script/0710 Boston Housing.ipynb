# %%
from tensorflow.keras.datasets import boston_housing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()

# %%
print(train_data.shape)
print(train_targets.shape)
print(test_data.shape)
print(test_targets.shape)
# Out:
# (404, 13)
# (404,)
# (102, 13)
# (102,)

# %%
plt.figure(figsize=(10,10))
plt.boxplot(train_data)
plt.show()

# %%
mean = train_data.mean()
sd = train_data.std()

# %%
tmp = (train_data-mean)/sd

# %%
df = pd.DataFrame(train_data)

# %%
df

# %%
mymean = list()
mystd = list()
for i in range(13):
    mymean.append(df[i].mean())
    mystd.append(df[i].std())
print(mymean)
print(mystd)
for i in range(13):
    df[i]=(df[i]-mymean[i])/mystd[i]
# Out:
# [3.74511056930693, 11.48019801980198, 11.104430693069308, 0.06188118811881188, 0.5573559405940595, 6.267081683168317, 69.01064356435644, 3.7402707920792078, 9.44059405940594, 405.8985148514852, 18.4759900990099, 354.7831683168317, 12.740816831683167]
# [9.240734365476436, 23.76771073136457, 6.8113075902852485, 0.24123838018033947, 0.1172931014679324, 0.7097876212337838, 27.940664897596562, 2.0302146977710325, 8.698360453797198, 166.37454262751086, 2.2003818211189303, 94.11114780831176, 7.254544811560667]

# %%
plt.figure(figsize=(9,9))
plt.boxplot([df[i] for i in df])
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.boxplot(tmp)
plt.show()

# %%
train_data.mean(axis=0)
# Out:
# array([3.74511057e+00, 1.14801980e+01, 1.11044307e+01, 6.18811881e-02,
#        5.57355941e-01, 6.26708168e+00, 6.90106436e+01, 3.74027079e+00,
#        9.44059406e+00, 4.05898515e+02, 1.84759901e+01, 3.54783168e+02,
#        1.27408168e+01])
